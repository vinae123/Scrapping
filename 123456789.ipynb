# %%
from time import sleep
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import pandas as pd

# %%
base_url = "https://www.amazon.in/s?k=bags&ref=sr_pg_1"
num_pages = 20

# %%
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run in headless mode (without opening browser window)
driver = webdriver.Chrome()

# %%
product_url = []
product_name = []
product_price = []
rating = []
num_reviews = []

# %%
# To get the url for the products 
# driver.get(base_url + str(1))
# element = driver.find_elements(By.XPATH,"//a[@class = 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal']")
driver.get(base_url)

# %%
# cards = soup.find_all('div', {'data-asin' : True , 'data-component-type' : 's-search-result'})
# for card in cards:
#     product_name.append(card.h2.text.strip())
#     product_url.append(card.h2.a.get('href'))

# %%
try:
    for page in range(1, num_pages + 1):        
        driver.get(driver.current_url)
        html = driver.page_source
        soup  = BeautifulSoup(html,'lxml')
        cards = soup.find_all('div', {'data-asin' : True , 'data-component-type' : 's-search-result'})
        for card in cards:
            try:
                product_name.append(card.h2.text.strip())
            except:
                product_name.append(None)
            try:
                product_url.append(card.h2.a.get('href'))
            except:
                product_url.append(None)
            try:
                product_price.append(card.find('span',class_ = 'a-price-whole').text)
            except:
                product_price.append(None)
            try:
                rating.append(card.find('span',class_ = 'a-icon-alt').text.strip('out of 5 stars'))
            except:
                rating.append(None)
            try:
                num_reviews.append(card.find('span',class_ = 'a-size-base s-underline-text').text)
            except:
                num_reviews.append(None)
        next = driver.find_element(By.LINK_TEXT ,'Next')
        next.click()        

        # #For Product_urls
        # urls = driver.find_elements(By.XPATH,"//a[@class = 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal']")
        # names = driver.find_elements(By.XPATH,"//span[@class = 'a-size-medium a-color-base a-text-normal']") #Names
        # for i in urls:
        #     # product_name.append(i.text())
        #     product_url.append(i.get_attribute('href') + '/n')
        # for j in names:
        #     product_name.append(j.text)
        # next = driver.find_element(By.LINK_TEXT ,'Next')
        # next.click()
except:
    pass

# %%
print(len(product_name))
print(len(product_url))
print(len(product_price))
print(len(rating))
print(len(num_reviews))
# Out:
# 426
# 426
# 426
# 426
# 426

# %%
df = pd.DataFrame({'Product Name' : product_name , 'URL': product_url , 'Price' : product_price , 'Ratings' : rating , 'Reviews' : num_reviews})
df.to_csv('Scraping')

# %%
Description = []
Product_ASIN = []
Product_Description = []
Manufacturer = []

# %%
# for i in df['URL']:
#     try:
#         url = 'https://www.amazon.in'+ i
#         driver2 = webdriver.Chrome()
#         driver2.get(url)
#         html = driver2.page_source
#         soup  = BeautifulSoup(html,'lxml')
#         # Description.append(soup.find('ul',class_ ='a-unordered-list a-vertical a-spacing-mini').text.strip())
#         li = soup.find('li',class_ = "a-unordered-list a-nostyle a-vertical a-spacing-none detail-bullet-list")
#     except:
#         print('Error')

# %%
# url = 'https://www.amazon.in/Skybags-Brat-Black-Casual-Backpack/dp/B08Z1HHHTD/ref=sr_1_5?keywords=bags&sr=8-5'
# driver2 = webdriver.Chrome()
# driver2.get(url)
# html = driver2.page_source
# soup  = BeautifulSoup(html,'lxml')
# # Description.append(soup.find('ul',class_ ='a-unordered-list a-vertical a-spacing-mini').text.strip())
# li = soup.find('ul',class_ = "a-unordered-list a-nostyle a-vertical a-spacing-none detail-bullet-list")
# for i in li:
#     print(i)
# else:
#     print('error')
# print(li)

# %%
li = soup.find('li',class_ = "a-unordered-list a-nostyle a-vertical a-spacing-none detail-bullet-list")

# %%
Description
# Out:
# []

# %%
# url = 'https://www.amazon.in'+ df['URL'][3]
# driver2 = webdriver.Chrome()
# driver2.get(url)
# html = driver2.page_source
# soup  = BeautifulSoup(html,'lxml')
# Description.append(soup.find('ul',class_ ='a-unordered-list a-vertical a-spacing-mini').text.strip())

# %%
# for page in range(1, num_pages + 1):
#     url = base_url + str(page)
#     driver.get(url)
#     sleep(3)  # Give the page some time to load
    
#     # Extract product details
#     product_elements = driver.find_elements(By.CSS_SELECTOR, '[data-component-type="s-search-result"]')
#     for element in product_elements:
#         try:
#             product_url.append(element.find_element(By.CSS_SELECTOR, 'sg-col-inner').get_attribute('href'))
#             product_name.append(element.find_element(By.CSS_SELECTOR, 'span.a-size-medium').text)
#             product_price.append(element.find_element(By.CSS_SELECTOR, 'span.a-price-whole').text)
#             rating.append(element.find_element(By.CSS_SELECTOR, 'span.a-icon-alt').get_attribute('innerHTML'))
#             num_reviews.append(element.find_element(By.CSS_SELECTOR, 'span.a-size-base').text.replace(',', ''))
            
#         except:
#             print(page)
#             continue

# %%
product_url
# Out:
# ['/sspa/click?ie=UTF8&spc=MTo0ODU0OTM1MDU2Mjk2MjY0OjE2ODUyMDkyOTk6c3BfYXRmOjIwMTE2ODgyMTgxMDk4OjowOjo&url=%2FRed-Lemon-Unisex-adult-Waterproof-Charging%2Fdp%2FB09VGNTDRZ%2Fref%3Dsr_1_1_sspa%3Fkeywords%3Dbags%26qid%3D1685209299%26sr%3D8-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1',
#  '/sspa/click?ie=UTF8&spc=MTo0ODU0OTM1MDU2Mjk2MjY0OjE2ODUyMDkyOTk6c3BfYXRmOjIwMTE2ODc5MTY5OTk4OjowOjo&url=%2FRed-Lemon-Multifunctional-Waterproof-Anti-Thief%2Fdp%2FB0B12VF374%2Fref%3Dsr_1_2_sspa%3Fkeywords%3Dbags%26qid%3D1685209299%26sr%3D8-2-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1',
#  '/Wesley-Milestone-Waterproof-Backpack-Business/dp/B084JGJ8PF/ref=sr_1_3?keywords=bags&qid=1685209299&sr=8-3',
#  '/American-Tourister-AMT-SCH-02/dp/B07CJCGM1M/ref=sr_1_4?keywords=bags&qid=1685209299&sr=8-4',
#  '/Skybags-Brat-Black-Casual-Backpack/dp/B08Z1HHHTD/ref=sr_1_5?keywords=bags&qid=1685209299&sr=8-5',
# ...
